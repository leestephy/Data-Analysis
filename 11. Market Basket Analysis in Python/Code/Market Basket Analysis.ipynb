# %% [markdown]
# ### Data Mining II with Market Basket Analysis
#
# By Stephanie Nguyen

# %% [markdown]
# ### A1. PROPOSAL OF QUESTION
# - What marketing insights can be gained from using market basket analysis to identify which telecom items were most frequently purchased together?

# %% [markdown]
# ### A2. DEFINED GOAL
# - Use market basket analysis to identify frequently purchased telecom items and optimize marketing strategies

# %% [markdown]
# ### B1. EXPLANATION OF MARKET BASKET
# - Market basket analysis uses if-then rules to find items that are often purchased together, identifying the antecedent and the consequent. This analysis provides insights into product placement and inventory management while improving marketing strategies through metrics like support, lift, and confidence, allowing for more targeted campaigns.

# %% [markdown]
# ### Importing packages and libraries

# %%
import pandas as pd
import numpy as np

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Load the dataset into a DataFrame
df = pd.read_csv(r'C:\Users\steph\Documents\GitHub\Data Analysis\11. Market Basket Analysis in Python\Data\teleco_market_basket.csv')
df.shape
# Out:
# (15002, 20)

# %%
df.head(5)
# Out:
#                                   Item01                            Item02  \
# 0                                    NaN                               NaN
# 1           Logitech M510 Wireless mouse                         HP 63 Ink
# 2                                    NaN                               NaN
# 3  Apple Lightning to Digital AV Adapter  TP-Link AC1750 Smart WiFi Router
# 4                                    NaN                               NaN
#
#          Item03                      Item04                     Item05  \
# 0           NaN                         NaN                        NaN
# 1     HP 65 ink  nonda USB C to USB Adapter  10ft iPHone Charger Cable
# 2           NaN                         NaN                        NaN
# 3  Apple Pencil                         NaN                        NaN
# 4           NaN                         NaN                        NaN
#
#          Item06                        Item07  \
# ...

# %%
# get overview of columns and data types in dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15002 entries, 0 to 15001
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Item01  7501 non-null   object
#  1   Item02  5747 non-null   object
#  2   Item03  4389 non-null   object
#  3   Item04  3345 non-null   object
#  4   Item05  2529 non-null   object
#  5   Item06  1864 non-null   object
#  6   Item07  1369 non-null   object
#  7   Item08  981 non-null    object
#  8   Item09  654 non-null    object
#  9   Item10  395 non-null    object
#  10  Item11  256 non-null    object
#  11  Item12  154 non-null    object
#  12  Item13  87 non-null     object
#  13  Item14  47 non-null     object
#  14  Item15  25 non-null     object
#  15  Item16  8 non-null      object
#  16  Item17  4 non-null      object
#  17  Item18  4 non-null      object
#  18  Item19  3 non-null      object
#  19  Item20  1 non-null      object
# dtypes: object(20)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Data Preprocessing

# %%
# remove empty rows
df = df[df['Item01'].notna()]
df.shape
# Out:
# (7501, 20)

# %%
df.head(5)
# Out:
#                                       Item01  \
# 1               Logitech M510 Wireless mouse
# 3      Apple Lightning to Digital AV Adapter
# 5  UNEN Mfi Certified 5-pack Lightning Cable
# 7                        Cat8 Ethernet Cable
# 9             Dust-Off Compressed Gas 2 pack
#
#                              Item02                      Item03  \
# 1                         HP 63 Ink                   HP 65 ink
# 3  TP-Link AC1750 Smart WiFi Router                Apple Pencil
# 5                               NaN                         NaN
# 7                         HP 65 ink                         NaN
# 9     Screen Mom Screen Cleaner kit  Moread HDMI to VGA Adapter
#
#                        Item04                     Item05        Item06  \
# 1  nonda USB C to USB Adapter  10ft iPHone Charger Cable  HP 902XL ink
# 3                         NaN                        NaN           NaN
# 5                         NaN                        NaN           NaN
# ...

# %% [markdown]
# ### B2. TRANSACTION EXAMPLE

# %%
df.head(1)
# Out:
#                          Item01     Item02     Item03  \
# 1  Logitech M510 Wireless mouse  HP 63 Ink  HP 65 ink
#
#                        Item04                     Item05        Item06  \
# 1  nonda USB C to USB Adapter  10ft iPHone Charger Cable  HP 902XL ink
#
#                          Item07                               Item08  \
# 1  Creative Pebble 2.0 Speakers  Cleaning Gel Universal Dust Cleaner
#
#                           Item09                                   Item10  \
# 1  Micro Center 32GB Memory card  YUNSONG 3pack 6ft Nylon Lightning Cable
#
#                          Item11                     Item12  \
# 1  TopMate C5 Laptop Cooler pad  Apple USB-C Charger cable
#
#                          Item13                       Item14  \
# 1  HyperX Cloud Stinger Headset  TONOR USB Gaming Microphone
#
#                            Item15                          Item16  \
# 1  Dust-Off Compressed Gas 2 pack  3A USB Type C Cable 3 pack 6FT
#
# ...

# %%
df.head(1).to_csv(r'C:\Users\steph\Documents\GitHub\Data Analysis\11. Market Basket Analysis in Python\Outputs\transaction_example.csv')

# %% [markdown]
# ### B3. MARKET BASKET ASSUMPTION
# - Market basket analysis assumes that items frequently purchased together are associated, indicating a meaningful relationship, even if they are not directly related.

# %% [markdown]
# ### C1. TRANSFORMING THE DATA SET

# %%
# convert to list of lists
rows = []
for i in range(0, 7501):
	rows.append([str(df.values[i,j])
for j in range(0, 20)])

# %%
# encode list
encoder = TransactionEncoder()
array = encoder.fit(rows).transform(rows)

# %%
# Convert array back to a DataFrame
pd.set_option('display.max_columns',None)
transaction = pd.DataFrame(array, columns = encoder.columns_)

transaction
# Out:
#       10ft iPHone Charger Cable  10ft iPHone Charger Cable 2 Pack  \
# 0                          True                             False
# 1                         False                             False
# 2                         False                             False
# 3                         False                             False
# 4                         False                             False
# ...                         ...                               ...
# 7496                      False                             False
# 7497                      False                             False
# 7498                      False                             False
# 7499                      False                             False
# 7500                      False                             False
#
#       3 pack Nylon Braided Lightning Cable  3A USB Type C Cable 3 pack 6FT  \
# 0                                    False                            True
# ...

# %%
# Display items as column
for col in transaction.columns:
	print(col)
# Out:
# 10ft iPHone Charger Cable
# 10ft iPHone Charger Cable 2 Pack
# 3 pack Nylon Braided Lightning Cable
# 3A USB Type C Cable 3 pack 6FT
# 5pack Nylon Braided USB C cables
# ARRIS SURFboard SB8200 Cable Modem
# Anker 2-in-1 USB Card Reader
# Anker 4-port USB hub
# Anker USB C to HDMI Adapter
# Apple Lightning to Digital AV Adapter
# Apple Lightning to USB cable
# Apple Magic Mouse 2
# Apple Pencil
# Apple Pencil 2nd Gen
# Apple Power Adapter Extension Cable
# Apple USB-C Charger cable
# AutoFocus 1080p Webcam
# BENGOO G90000 headset
# Blue Light Blocking Glasses
# Blue Light Blocking Glasses 2pack
# Brother Genuine High Yield Toner Cartridge
# Cat 6 Ethernet Cable 50ft
# Cat8 Ethernet Cable
# CicTsing MM057 2.4G Wireless Mouse
# Cleaning Gel Universal Dust Cleaner
# Creative Pebble 2.0 Speakers
# DisplayPort ot HDMI adapter
# Dust-Off Compressed Gas
# Dust-Off Compressed Gas 2 pack
# FEEL2NICE 5 pack 10ft Lighning cable
# FEIYOLD Blue light Blocking Glasses
# ...

# %%
# Remove nan column from transformed dataset
df_clean = transaction.drop(['nan'], axis = 1)
df_clean.head()
df_clean.shape
# Out:
# (7501, 119)

# %%
# Write transformed dataset to CSV
df_clean.to_csv(r'C:\Users\steph\Documents\GitHub\Data Analysis\11. Market Basket Analysis in Python\Outputs\df_clean.csv')
df_clean.columns
# Out:
# Index(['10ft iPHone Charger Cable', '10ft iPHone Charger Cable 2 Pack',
#        '3 pack Nylon Braided Lightning Cable',
#        '3A USB Type C Cable 3 pack 6FT', '5pack Nylon Braided USB C cables',
#        'ARRIS SURFboard SB8200 Cable Modem', 'Anker 2-in-1 USB Card Reader',
#        'Anker 4-port USB hub', 'Anker USB C to HDMI Adapter',
#        'Apple Lightning to Digital AV Adapter',
#        ...
#        'hP 65 Tri-color ink', 'iFixit Pro Tech Toolkit', 'iPhone 11 case',
#        'iPhone 12 Charger cable', 'iPhone 12 Pro case', 'iPhone 12 case',
#        'iPhone Charger Cable Anker 6ft', 'iPhone SE case',
#        'nonda USB C to USB Adapter', 'seenda Wireless mouse'],
#       dtype='object', length=119)

# %% [markdown]
# ### C2. CODE EXECUTION

# %%
# Create Apriori object called rules
rules = apriori(df_clean, min_support = 0.02, use_colnames = True)
rules.head(5)
# Out:
#     support                                 itemsets
# 0  0.050527       (10ft iPHone Charger Cable 2 Pack)
# 1  0.042528         (3A USB Type C Cable 3 pack 6FT)
# 2  0.029463           (Anker 2-in-1 USB Card Reader)
# 3  0.068391            (Anker USB C to HDMI Adapter)
# 4  0.087188  (Apple Lightning to Digital AV Adapter)

# %% [markdown]
# ### C3. ASSOCIATION RULES TABLE

# %%
# Create a rules table
# metric set to lift b/c the higher the lift, the stronger the likelihood of the items getting purchased together
# any rule below 1 will not be considered
rules_table = association_rules(rules, metric = 'lift', min_threshold = 1)
rules_table.head(10)
# Out:
#                                antecedents  \
# 0       (10ft iPHone Charger Cable 2 Pack)
# 1         (Dust-Off Compressed Gas 2 pack)
# 2            (Anker USB C to HDMI Adapter)
# 3         (Dust-Off Compressed Gas 2 pack)
# 4            (Anker USB C to HDMI Adapter)
# 5       (VIVO Dual LCD Monitor Desk mount)
# 6  (Apple Lightning to Digital AV Adapter)
# 7                           (Apple Pencil)
# 8  (Apple Lightning to Digital AV Adapter)
# 9         (Dust-Off Compressed Gas 2 pack)
#
#                                consequents  antecedent support  \
# 0         (Dust-Off Compressed Gas 2 pack)            0.050527
# 1       (10ft iPHone Charger Cable 2 Pack)            0.238368
# 2         (Dust-Off Compressed Gas 2 pack)            0.068391
# 3            (Anker USB C to HDMI Adapter)            0.238368
# 4       (VIVO Dual LCD Monitor Desk mount)            0.068391
# 5            (Anker USB C to HDMI Adapter)            0.174110
# ...

# %% [markdown]
# ### C4. TOP THREE RULES

# %%
top_three_rules = rules_table.sort_values('support', ascending = False).head(3)
top_three_rules
# Out:
#                            antecedents                         consequents  \
# 62  (VIVO Dual LCD Monitor Desk mount)    (Dust-Off Compressed Gas 2 pack)
# 63    (Dust-Off Compressed Gas 2 pack)  (VIVO Dual LCD Monitor Desk mount)
# 41    (Dust-Off Compressed Gas 2 pack)                         (HP 61 ink)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 62            0.174110            0.238368  0.059725    0.343032  1.439085
# 63            0.238368            0.174110  0.059725    0.250559  1.439085
# 41            0.238368            0.163845  0.052660    0.220917  1.348332
#
#     leverage  conviction  zhangs_metric
# 62  0.018223    1.159314       0.369437
# 63  0.018223    1.102008       0.400606
# 41  0.013604    1.073256       0.339197

# %%
top_three_rules = rules_table.sort_values('lift', ascending = False).head(3)
top_three_rules
# Out:
#                               antecedents                         consequents  \
# 84     (VIVO Dual LCD Monitor Desk mount)           (SanDisk Ultra 64GB card)
# 85              (SanDisk Ultra 64GB card)  (VIVO Dual LCD Monitor Desk mount)
# 65  (FEIYOLD Blue light Blocking Glasses)  (VIVO Dual LCD Monitor Desk mount)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 84            0.174110            0.098254  0.039195    0.225115  2.291162
# 85            0.098254            0.174110  0.039195    0.398915  2.291162
# 65            0.065858            0.174110  0.022930    0.348178  1.999758
#
#     leverage  conviction  zhangs_metric
# 84  0.022088    1.163716       0.682343
# 85  0.022088    1.373997       0.624943
# 65  0.011464    1.267048       0.535186

# %%
# Sorting rules by metric in descending order
top_three_rules = rules_table.sort_values('confidence', ascending = False).head(3)
top_three_rules
# Out:
#                               antecedents                       consequents  \
# 0      (10ft iPHone Charger Cable 2 Pack)  (Dust-Off Compressed Gas 2 pack)
# 36  (FEIYOLD Blue light Blocking Glasses)  (Dust-Off Compressed Gas 2 pack)
# 53              (SanDisk Ultra 64GB card)  (Dust-Off Compressed Gas 2 pack)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.050527            0.238368  0.023064    0.456464  1.914955
# 36            0.065858            0.238368  0.027596    0.419028  1.757904
# 53            0.098254            0.238368  0.040928    0.416554  1.747522
#
#     leverage  conviction  zhangs_metric
# 0   0.011020    1.401255       0.503221
# 36  0.011898    1.310962       0.461536
# 53  0.017507    1.305401       0.474369

# %% [markdown]
# ### D1. SIGNIFICANCE OF FINDINGS
# - **Support**: The leading support-based rules show that customers purchasing a Dust-Off Compressed Gas 2 pack are likely to also buy a VIVO Dual LCD Monitor Desk mount and HP 61 ink, with support values of 0.059725 and 0.052660, indicating that about 6% of transactions involve these items together.
#
# - **Lift**: The primary rules derived from the lift metric demonstrate strong associations, such as when purchasing a VIVO Dual LCD Monitor Desk mount, which has a lift value of 2.291162 with a SanDisk Ultra 64GB card, suggesting that these items are significantly more likely to be bought together than by chance.
#
# - **Confidence**: The confidence metric indicates a 45.6% probability that customers buying a 10ft iPhone Charger Cable 2 Pack will also purchase a Dust-Off Compressed Gas 2 pack. While this suggests a notable relationship, the confidence levels of 41.9% for FEIYOLD Blue Light Blocking Glasses and 41.6% for the SanDisk Ultra 64GB card indicate that these associations may not be particularly strong, as none exceed the 50% threshold

# %% [markdown]
# ### D2. PRACTICAL SIGNIFICANCE OF FINDINGS
# - **Substantial Co-Purchases**: With 7,501 transactions, a support value of 5-6% indicates that approximately 375 to 450 transactions involve associated items being purchased together, reflecting a significant pattern of co-purchases.
#
# - **Strong Lift Associations**: The lift metric shows all three rules have lift values around 2, meaning the associated items are about twice as likely to be purchased together compared to independently.
#
# - **Weak Confidence Correlation**: Although there is a reasonable likelihood of purchasing a Dust-Off Compressed Gas 2 pack alongside items like the 10ft iPhone Charger Cable 2 Pack and FEIYOLD Blue Light Blocking Glasses, the confidence values are below 50%, indicating a weaker correlation.

# %% [markdown]
# ### D3. COURSE OF ACTION
# - A support value of 5-6% from 7,501 transactions indicates that around 375 to 450 purchases involve the VIVO Dual LCD Monitor Desk Mount, HP 62 Ink, and Dust-Off Compressed Gas 2 pack being bought together.
# - This strong association provides opportunities for targeted marketing strategies like cross-selling and bundling to boost sales.
# - The lift metric suggests that marketing teams should place frequently purchased pairs, such as the VIVO Dual LCD Monitor Desk Mount, SanDisk Ultra 64GB card, and FEIYOLD Blue Light Blocking Glasses, close together in stores to optimize sales.
